# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('datasets/movielens_original/ratings-1M.csv')
df_movie = pd.read_csv('datasets/movielens_original/movies-1M.csv')

# %%
df = df.merge(df_movie, how="left", on="movieId")

# %%
df_train, df_val = train_test_split(df, random_state=42, test_size=0.2, stratify=df.rating)

# %%
movies_ids = list(set(list(df_train.movieId.unique()) + list(df_val.movieId.unique())))
users_ids = list(set(list(df_train.userId.unique()) + list(df_val.userId.unique())))

dict_movies = {}
index = 0

for ids in sorted(movies_ids):
    dict_movies[ids] = index
    index += 1

dict_users = {}
index = 0
for ids in sorted(users_ids):
    dict_users[ids] = index
    index += 1

df_train["movieId"] = df_train["movieId"].map(dict_movies)
df_val["movieId"] = df_val["movieId"].map(dict_movies)

df_train["userId"] = df_train["userId"].map(dict_users)
df_val["userId"] = df_val["userId"].map(dict_users)

# %%
for col in ["userId", "movieId", "rating"]:
    df_train[col] = df_train[col].astype(np.float32)
    df_val[col] = df_val[col].astype(np.float32)


num_unique_users = len(set(list(df_train.userId.unique()) + list(df_val.userId.unique())))
num_unique_movies = len(set(list(df_train.movieId.unique()) + list(df_val.movieId.unique())))

min_rating=min(df_train.rating.min(), df_val.rating.min())
max_rating=max(df_train.rating.max(), df_val.rating.max())

# %%
import tensorflow as tf
from tensorflow.keras import Model, regularizers
from tensorflow.keras import optimizers as opt
from tensorflow.keras.layers import Embedding, multiply, concatenate, Flatten, Input, Dense

# %%
EMBEDDING_SIZE = 50

users_input = Input(shape=(1,), name="users_input")
users_embedding = Embedding(
    num_unique_users + 1, 
    EMBEDDING_SIZE, 
    name="users_embeddings"
)(users_input)
users_bias = Embedding(num_unique_users + 1, 1, name="users_bias")(users_input)

movies_input = Input(shape=(1,), name="movies_input")
movies_embedding = Embedding(
    num_unique_movies + 1, 
    EMBEDDING_SIZE, 
    name="movies_embeddings"
)(movies_input)
movies_bias = Embedding(num_unique_movies + 1, 1, name="movies_bias")(movies_input)

dot_product_users_movies = multiply([users_embedding, movies_embedding])

input_terms = dot_product_users_movies + users_bias + movies_bias

input_terms = Flatten(name="fl_inputs")(input_terms)

output = Dense(1, activation="sigmoid", name="output")(input_terms) 
output = output * (max_rating - min_rating) + min_rating

# %%
model = Model(inputs=[users_input, movies_input], outputs=output)

opt_adam = opt.Adam(learning_rate = 0.01)
model.compile(
    optimizer=opt_adam, 
    loss= ['mse'], 
    metrics=['mean_absolute_error']
)

# %%
model.fit(
    x=[df_train.userId, df_train.movieId], 
    y=df_train.rating, 
    batch_size=30000, 
    epochs=100, 
    verbose=1,
    validation_data=([df_val.userId, df_val.movieId], df_val.rating)
)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0094 - mean_absolute_error: 0.0487 - val_loss: 1.1354 - val_mean_absolute_error: 0.8174
# Epoch 2/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0092 - mean_absolute_error: 0.0482 - val_loss: 1.1382 - val_mean_absolute_error: 0.8183
# Epoch 3/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0091 - mean_absolute_error: 0.0477 - val_loss: 1.1408 - val_mean_absolute_error: 0.8192
# Epoch 4/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0089 - mean_absolute_error: 0.0471 - val_loss: 1.1435 - val_mean_absolute_error: 0.8202
# Epoch 5/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0088 - mean_absolute_error: 0.0467 - val_loss: 1.1463 - val_mean_absolute_error: 0.8211
# Epoch 6/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0086 - mean_absolute_error: 0.0461 - val_loss: 1.1489 - val_mean_absolute_error: 0.8220
# Epoch 7/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0085 - mean_absolute_error: 0.0457 - val_loss: 1.1514 - val_mean_absolute_error: 0.8228
# Epoch 8/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0083 - mean_absolute_error: 0.0452 - val_loss: 1.1540 - val_mean_absolute_error: 0.8237
# Epoch 9/100
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0082 - mean_absolute_error: 0.0447 - val_loss: 1.1566 - val_mean_absolute_error: 0.8247
# Epoch 10/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0081 - mean_absolute_error: 0.0443 - val_loss: 1.1591 - val_mean_absolute_error: 0.8255
# Epoch 11/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0080 - mean_absolute_error: 0.0438 - val_loss: 1.1616 - val_mean_absolute_error: 0.8263
# Epoch 12/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0078 - mean_absolute_error: 0.0433 - val_loss: 1.1641 - val_mean_absolute_error: 0.8272
# Epoch 13/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0077 - mean_absolute_error: 0.0429 - val_loss: 1.1665 - val_mean_absolute_error: 0.8280
# Epoch 14/100
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0076 - mean_absolute_error: 0.0424 - val_loss: 1.1691 - val_mean_absolute_error: 0.8288
# Epoch 15/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0075 - mean_absolute_error: 0.0420 - val_loss: 1.1715 - val_mean_absolute_error: 0.8297
# Epoch 16/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0074 - mean_absolute_error: 0.0416 - val_loss: 1.1739 - val_mean_absolute_error: 0.8304
# Epoch 17/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0073 - mean_absolute_error: 0.0413 - val_loss: 1.1762 - val_mean_absolute_error: 0.8312
# Epoch 18/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0071 - mean_absolute_error: 0.0409 - val_loss: 1.1786 - val_mean_absolute_error: 0.8320
# Epoch 19/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0070 - mean_absolute_error: 0.0404 - val_loss: 1.1810 - val_mean_absolute_error: 0.8328
# Epoch 20/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0070 - mean_absolute_error: 0.0401 - val_loss: 1.1832 - val_mean_absolute_error: 0.8336
# Epoch 21/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0068 - mean_absolute_error: 0.0398 - val_loss: 1.1855 - val_mean_absolute_error: 0.8343
# Epoch 22/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0067 - mean_absolute_error: 0.0393 - val_loss: 1.1880 - val_mean_absolute_error: 0.8352
# Epoch 23/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0067 - mean_absolute_error: 0.0390 - val_loss: 1.1903 - val_mean_absolute_error: 0.8360
# Epoch 24/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0066 - mean_absolute_error: 0.0387 - val_loss: 1.1925 - val_mean_absolute_error: 0.8367
# Epoch 25/100
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0065 - mean_absolute_error: 0.0383 - val_loss: 1.1948 - val_mean_absolute_error: 0.8375
# Epoch 26/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0064 - mean_absolute_error: 0.0380 - val_loss: 1.1970 - val_mean_absolute_error: 0.8382
# Epoch 27/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0063 - mean_absolute_error: 0.0377 - val_loss: 1.1992 - val_mean_absolute_error: 0.8390
# Epoch 28/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0062 - mean_absolute_error: 0.0373 - val_loss: 1.2014 - val_mean_absolute_error: 0.8397
# Epoch 29/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0061 - mean_absolute_error: 0.0370 - val_loss: 1.2035 - val_mean_absolute_error: 0.8404
# Epoch 30/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0061 - mean_absolute_error: 0.0367 - val_loss: 1.2057 - val_mean_absolute_error: 0.8411
# Epoch 31/100
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0060 - mean_absolute_error: 0.0363 - val_loss: 1.2077 - val_mean_absolute_error: 0.8418
# Epoch 32/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0059 - mean_absolute_error: 0.0360 - val_loss: 1.2098 - val_mean_absolute_error: 0.8425
# Epoch 33/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0058 - mean_absolute_error: 0.0358 - val_loss: 1.2120 - val_mean_absolute_error: 0.8432
# Epoch 34/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0057 - mean_absolute_error: 0.0354 - val_loss: 1.2142 - val_mean_absolute_error: 0.8439
# Epoch 35/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0056 - mean_absolute_error: 0.0351 - val_loss: 1.2162 - val_mean_absolute_error: 0.8446
# Epoch 36/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0056 - mean_absolute_error: 0.0349 - val_loss: 1.2182 - val_mean_absolute_error: 0.8453
# Epoch 37/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0055 - mean_absolute_error: 0.0346 - val_loss: 1.2204 - val_mean_absolute_error: 0.8460
# Epoch 38/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0055 - mean_absolute_error: 0.0344 - val_loss: 1.2225 - val_mean_absolute_error: 0.8467
# Epoch 39/100
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0054 - mean_absolute_error: 0.0341 - val_loss: 1.2243 - val_mean_absolute_error: 0.8473
# Epoch 40/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0053 - mean_absolute_error: 0.0338 - val_loss: 1.2263 - val_mean_absolute_error: 0.8480
# Epoch 41/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0053 - mean_absolute_error: 0.0335 - val_loss: 1.2285 - val_mean_absolute_error: 0.8487
# Epoch 42/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0052 - mean_absolute_error: 0.0333 - val_loss: 1.2304 - val_mean_absolute_error: 0.8493
# Epoch 43/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0051 - mean_absolute_error: 0.0330 - val_loss: 1.2322 - val_mean_absolute_error: 0.8499
# Epoch 44/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0051 - mean_absolute_error: 0.0328 - val_loss: 1.2342 - val_mean_absolute_error: 0.8505
# Epoch 45/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0050 - mean_absolute_error: 0.0324 - val_loss: 1.2362 - val_mean_absolute_error: 0.8512
# Epoch 46/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0049 - mean_absolute_error: 0.0323 - val_loss: 1.2382 - val_mean_absolute_error: 0.8519
# Epoch 47/100
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0049 - mean_absolute_error: 0.0320 - val_loss: 1.2401 - val_mean_absolute_error: 0.8525
# Epoch 48/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0048 - mean_absolute_error: 0.0318 - val_loss: 1.2420 - val_mean_absolute_error: 0.8531
# Epoch 49/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0048 - mean_absolute_error: 0.0316 - val_loss: 1.2439 - val_mean_absolute_error: 0.8537
# Epoch 50/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0047 - mean_absolute_error: 0.0313 - val_loss: 1.2458 - val_mean_absolute_error: 0.8543
# Epoch 51/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0047 - mean_absolute_error: 0.0311 - val_loss: 1.2475 - val_mean_absolute_error: 0.8549
# Epoch 52/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0046 - mean_absolute_error: 0.0309 - val_loss: 1.2495 - val_mean_absolute_error: 0.8556
# Epoch 53/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0046 - mean_absolute_error: 0.0307 - val_loss: 1.2513 - val_mean_absolute_error: 0.8562
# Epoch 54/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0046 - mean_absolute_error: 0.0306 - val_loss: 1.2532 - val_mean_absolute_error: 0.8568
# Epoch 55/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0045 - mean_absolute_error: 0.0303 - val_loss: 1.2549 - val_mean_absolute_error: 0.8573
# Epoch 56/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0045 - mean_absolute_error: 0.0302 - val_loss: 1.2567 - val_mean_absolute_error: 0.8579
# Epoch 57/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0044 - mean_absolute_error: 0.0300 - val_loss: 1.2584 - val_mean_absolute_error: 0.8585
# Epoch 58/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0044 - mean_absolute_error: 0.0299 - val_loss: 1.2601 - val_mean_absolute_error: 0.8590
# Epoch 59/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0043 - mean_absolute_error: 0.0296 - val_loss: 1.2620 - val_mean_absolute_error: 0.8596
# Epoch 60/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0043 - mean_absolute_error: 0.0294 - val_loss: 1.2639 - val_mean_absolute_error: 0.8603
# Epoch 61/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0042 - mean_absolute_error: 0.0292 - val_loss: 1.2654 - val_mean_absolute_error: 0.8608
# Epoch 62/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0042 - mean_absolute_error: 0.0292 - val_loss: 1.2672 - val_mean_absolute_error: 0.8613
# Epoch 63/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0042 - mean_absolute_error: 0.0290 - val_loss: 1.2690 - val_mean_absolute_error: 0.8619
# Epoch 64/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0041 - mean_absolute_error: 0.0288 - val_loss: 1.2707 - val_mean_absolute_error: 0.8625
# Epoch 65/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0040 - mean_absolute_error: 0.0285 - val_loss: 1.2723 - val_mean_absolute_error: 0.8631
# Epoch 66/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0040 - mean_absolute_error: 0.0284 - val_loss: 1.2741 - val_mean_absolute_error: 0.8636
# Epoch 67/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0040 - mean_absolute_error: 0.0283 - val_loss: 1.2757 - val_mean_absolute_error: 0.8642
# Epoch 68/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0040 - mean_absolute_error: 0.0281 - val_loss: 1.2774 - val_mean_absolute_error: 0.8647
# Epoch 69/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0039 - mean_absolute_error: 0.0279 - val_loss: 1.2792 - val_mean_absolute_error: 0.8653
# Epoch 70/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0039 - mean_absolute_error: 0.0276 - val_loss: 1.2808 - val_mean_absolute_error: 0.8658
# Epoch 71/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0038 - mean_absolute_error: 0.0275 - val_loss: 1.2825 - val_mean_absolute_error: 0.8664
# Epoch 72/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0038 - mean_absolute_error: 0.0273 - val_loss: 1.2843 - val_mean_absolute_error: 0.8670
# Epoch 73/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0037 - mean_absolute_error: 0.0271 - val_loss: 1.2858 - val_mean_absolute_error: 0.8674
# Epoch 74/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0037 - mean_absolute_error: 0.0270 - val_loss: 1.2873 - val_mean_absolute_error: 0.8680
# Epoch 75/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0037 - mean_absolute_error: 0.0267 - val_loss: 1.2893 - val_mean_absolute_error: 0.8687
# Epoch 76/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0037 - mean_absolute_error: 0.0266 - val_loss: 1.2909 - val_mean_absolute_error: 0.8692
# Epoch 77/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0036 - mean_absolute_error: 0.0265 - val_loss: 1.2923 - val_mean_absolute_error: 0.8696
# Epoch 78/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0036 - mean_absolute_error: 0.0264 - val_loss: 1.2939 - val_mean_absolute_error: 0.8702
# Epoch 79/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0036 - mean_absolute_error: 0.0262 - val_loss: 1.2957 - val_mean_absolute_error: 0.8708
# Epoch 80/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0036 - mean_absolute_error: 0.0261 - val_loss: 1.2973 - val_mean_absolute_error: 0.8713
# Epoch 81/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0035 - mean_absolute_error: 0.0259 - val_loss: 1.2990 - val_mean_absolute_error: 0.8718
# Epoch 82/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0035 - mean_absolute_error: 0.0257 - val_loss: 1.3003 - val_mean_absolute_error: 0.8722
# Epoch 83/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0035 - mean_absolute_error: 0.0256 - val_loss: 1.3016 - val_mean_absolute_error: 0.8727
# Epoch 84/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0034 - mean_absolute_error: 0.0255 - val_loss: 1.3032 - val_mean_absolute_error: 0.8732
# Epoch 85/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0034 - mean_absolute_error: 0.0253 - val_loss: 1.3050 - val_mean_absolute_error: 0.8738
# Epoch 86/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0034 - mean_absolute_error: 0.0251 - val_loss: 1.3065 - val_mean_absolute_error: 0.8743
# Epoch 87/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0033 - mean_absolute_error: 0.0250 - val_loss: 1.3079 - val_mean_absolute_error: 0.8747
# Epoch 88/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0033 - mean_absolute_error: 0.0249 - val_loss: 1.3094 - val_mean_absolute_error: 0.8752
# Epoch 89/100
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0033 - mean_absolute_error: 0.0248 - val_loss: 1.3107 - val_mean_absolute_error: 0.8756
# Epoch 90/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0033 - mean_absolute_error: 0.0247 - val_loss: 1.3123 - val_mean_absolute_error: 0.8761
# Epoch 91/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0033 - mean_absolute_error: 0.0245 - val_loss: 1.3139 - val_mean_absolute_error: 0.8767
# Epoch 92/100
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0032 - mean_absolute_error: 0.0244 - val_loss: 1.3152 - val_mean_absolute_error: 0.8771
# Epoch 93/100
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0032 - mean_absolute_error: 0.0243 - val_loss: 1.3165 - val_mean_absolute_error: 0.8776
# Epoch 94/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0032 - mean_absolute_error: 0.0241 - val_loss: 1.3182 - val_mean_absolute_error: 0.8781
# Epoch 95/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0031 - mean_absolute_error: 0.0240 - val_loss: 1.3196 - val_mean_absolute_error: 0.8785
# Epoch 96/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0031 - mean_absolute_error: 0.0239 - val_loss: 1.3209 - val_mean_absolute_error: 0.8789
# Epoch 97/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0031 - mean_absolute_error: 0.0237 - val_loss: 1.3223 - val_mean_absolute_error: 0.8794
# Epoch 98/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0031 - mean_absolute_error: 0.0237 - val_loss: 1.3239 - val_mean_absolute_error: 0.8799
# Epoch 99/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0030 - mean_absolute_error: 0.0235 - val_loss: 1.3252 - val_mean_absolute_error: 0.8804
# Epoch 100/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0030 - mean_absolute_error: 0.0235 - val_loss: 1.3265 - val_mean_absolute_error: 0.8808

# %%
dict_weights = {}
for layer in model.layers:
    if layer.name in ["users_embeddings", "movies_embeddings"]:
        dict_weights[layer.name] = layer.weights

# %%
df_movies_embeddings = pd.DataFrame(dict_weights["movies_embeddings"][0].numpy())
df_movies_embeddings.columns = ["emb_" + str(col) for col in df_movies_embeddings.columns]
df_movies_embeddings.reset_index(inplace=True)
df_movies_embeddings.rename(columns={"index":"movieId"}, inplace=True)
df_movies_embeddings = df_movies_embeddings.merge(df_train[["movieId", "title"]].drop_duplicates(), how="left", on="movieId")

# %%
from sklearn.cluster import KMeans
km = KMeans(100)
km.fit(df_movies_embeddings[[col for col in df_movies_embeddings.columns if "emb" in col]])
clusters = km.predict(df_movies_embeddings[[col for col in df_movies_embeddings.columns if "emb" in col]])

# %%
df_movies_embeddings["cluster_n10"] = clusters

# %%
df_movies_embeddings[df_movies_embeddings.cluster_n10==49].title.unique()
# Out:
# array(['City of Lost Children, The (Cité des enfants perdus, La) (1995)',
#        'Flirting With Disaster (1996)', 'Hoop Dreams (1994)',
#        'Barcelona (1994)', 'Fresh (1994)', 'Apartment, The (1960)',
#        'Conan the Barbarian (1982)', 'Office Space (1999)',
#        'Long Goodbye, The (1973)', 'Run Lola Run (Lola rennt) (1998)',
#        'Mystery Men (1999)', 'Man on the Moon (1999)',
#        'Adventures of Baron Munchausen, The (1988)', 'Top Secret! (1984)',
#        'Adaptation (2002)', 'Millennium Actress (Sennen joyû) (2001)',
#        'Tokyo Godfathers (2003)', 'Chorus, The (Choristes, Les) (2004)',
#        'Paprika (Papurika) (2006)', 'Once (2006)',
#        "Futurama: Bender's Big Score (2007)", 'Gran Torino (2008)',
#        'Ponyo (Gake no ue no Ponyo) (2008)',
#        'Timecrimes (Cronocrímenes, Los) (2007)',
#        'Imaginarium of Doctor Parnassus, The (2009)',
#        'Secret in Their Eyes, The (El secreto de sus ojos) (2009)',
#        'Paper Birds (Pájaros de papel) (2010)', 'Eva (2011)',
#        'Life of Pi (2012)'], dtype=object)

# %%
df_movies_embeddings[df_movies_embeddings.title == 'Star Wars: Episode IV - A New Hope (1977)'].cluster_n10.values[0]
# Out:
# 84

# %%
df_movies_embeddings[df_movies_embeddings.cluster_n10==df_movies_embeddings[df_movies_embeddings.title == 'Doctor Strange (2016)'].cluster_n10.values[0]].title.unique()
# Out:
# array(['Disclosure (1994)', 'Clear and Present Danger (1994)',
#        'Crow, The (1994)', 'Addams Family Values (1993)',
#        'Last Action Hero (1993)', 'Rock, The (1996)',
#        'Basic Instinct (1992)', 'Crying Game, The (1992)',
#        'Snake Eyes (1998)', 'Star Trek: Insurrection (1998)',
#        'Pet Sematary (1989)', 'Invasion of the Body Snatchers (1956)',
#        'Arlington Road (1999)', 'Bull Durham (1988)',
#        'Creature Comforts (1989)',
#        "On Her Majesty's Secret Service (1969)", 'X-Men (2000)',
#        "Bill & Ted's Bogus Journey (1991)", 'I Am Sam (2001)',
#        'The Count of Monte Cristo (2002)',
#        'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)',
#        'National Treasure (2004)', 'History of Violence, A (2005)',
#        'Over the Hedge (2006)', 'Stranger than Fiction (2006)',
#        "Ocean's Thirteen (2007)", 'Stardust (2007)',
#        'Madagascar: Escape 2 Africa (2008)', 'Star Trek (2009)',
#        'Rio (2011)', 'Thor (2011)', 'Kung Fu Panda 2 (2011)',
#        "Dr. Seuss' The Lorax (2012)", 'Dictator, The (2012)',
#        'Brave (2012)', 'Taken 2 (2012)', 'Rise of the Guardians (2012)',
#        'Croods, The (2013)', 'Monsters University (2013)',
#        'Day of the Doctor, The (2013)',
#        'Captain America: The Winter Soldier (2014)',
#        'Penguins of Madagascar (2014)', 'Taken 3 (2015)',
#        'Avengers: Age of Ultron (2015)', 'Black Panther (2017)',
#        'Doctor Strange (2016)', 'Home (2015)',
#        'Kung Fu Panda: Secrets of the Masters (2011)',
#        'Kung Fu Panda 3 (2016)', 'Zootopia (2016)', 'Jason Bourne (2016)',
#        'The Boss Baby (2017)', 'Solo: A Star Wars Story (2018)'],
#       dtype=object)

# %%
df_movie[df_movie.title.apply(lambda x: 'Star Wars' in x)]
# Out:
#       movieId                                              title  \
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 898      1196  Star Wars: Episode V - The Empire Strikes Back...
# 911      1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 1979     2628   Star Wars: Episode I - The Phantom Menace (1999)
# 3832     5378  Star Wars: Episode II - Attack of the Clones (...
# 5896    33493  Star Wars: Episode III - Revenge of the Sith (...
# 6823    61160                   Star Wars: The Clone Wars (2008)
# 7367    79006  Empire of Dreams: The Story of the 'Star Wars'...
# 8683   122886  Star Wars: Episode VII - The Force Awakens (2015)
# 8908   135216               The Star Wars Holiday Special (1978)
# 9433   166528                Rogue One: A Star Wars Story (2016)
# 9645   179819                    Star Wars: The Last Jedi (2017)
# 9710   187595                     Solo: A Star Wars Story (2018)
#
#                                     genres
# 224                Action|Adventure|Sci-Fi
# 898                Action|Adventure|Sci-Fi
# 911                Action|Adventure|Sci-Fi
# 1979               Action|Adventure|Sci-Fi
# 3832          Action|Adventure|Sci-Fi|IMAX
# 5896               Action|Adventure|Sci-Fi
# 6823     Action|Adventure|Animation|Sci-Fi
# 7367                           Documentary
# 8683  Action|Adventure|Fantasy|Sci-Fi|IMAX
# 8908      Adventure|Children|Comedy|Sci-Fi
# 9433       Action|Adventure|Fantasy|Sci-Fi
# 9645       Action|Adventure|Fantasy|Sci-Fi
# 9710      Action|Adventure|Children|Sci-Fi

# %%
user_ids = df["userId"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
movie_ids = df["movieId"].unique().tolist()
movie2movie_encoded = {x: i for i, x in enumerate(movie_ids)}
movie_encoded2movie = {i: x for i, x in enumerate(movie_ids)}

# %%
# Let us get a user and see the top recommendations.
# user_id = ratings.userId.sample(1).iloc[0]
user_id = 252
movies_watched_by_user = df[df.userId == user_id]
movies_not_watched = df_movie[
    ~df_movie["movieId"].isin(movies_watched_by_user.movieId.values)
]["movieId"]
movies_not_watched = list(
    set(movies_not_watched).intersection(set(movie2movie_encoded.keys()))
)
#  mungkin salah di 2 paragraf di bawah vvvvv=============================================================================================================vvvvv
movies_not_watched = [[movie2movie_encoded.get(x)] for x in movies_not_watched]
user_encoder = user2user_encoded.get(user_id)
user_movie_array = np.hstack(
    ([[user_encoder]] * len(movies_not_watched), movies_not_watched)
)
result = model.predict([df_train.userId, df_train.movieId]).flatten()
top_ratings_indices = result.argsort()[-15:][::-1]
recommended_movie_ids = [
    movie_encoded2movie.get(movies_not_watched[x][0]) for x in top_ratings_indices
]

print("Showing recommendations for user: {}".format(user_id))
print("====" * 9)
print("Movies with high ratings from user")
print("----" * 8)
top_movies_user = (
    movies_watched_by_user.sort_values(by="rating", ascending=False)
    .head(5)
    .movieId.values
)
movies_rows = movies[movies["movieId"].isin(top_movies_user)]
for row in movies_rows.itertuples():
    print(row.title, ":", row.genres)

print("----" * 8)
print("Top 10 movie recommendations")
print("----" * 8)
recommended_movies = movies[movies["movieId"].isin(recommended_movie_ids)]
for row in recommended_movies.itertuples():
    print(row.title, ":", row.genres)
# Out:
# 2521/2521 [==============================] - 3s 1ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 19
#      17 result = model.predict([df_train.userId, df_train.movieId]).flatten()
#      18 top_ratings_indices = result.argsort()[-15:][::-1]
# ---> 19 recommended_movie_ids = [
#      20     movie_encoded2movie.get(movies_not_watched[x][0]) for x in top_ratings_indices
#      21 ]
#      23 print("Showing recommendations for user: {}".format(user_id))
#      24 print("====" * 9)
#
# Cell In[91], line 20, in <listcomp>(.0)
#      17 result = model.predict([df_train.userId, df_train.movieId]).flatten()
#      18 top_ratings_indices = result.argsort()[-15:][::-1]
#      19 recommended_movie_ids = [
# ---> 20     movie_encoded2movie.get(movies_not_watched[x][0]) for x in top_ratings_indices
#      21 ]
#      23 print("Showing recommendations for user: {}".format(user_id))
#      24 print("====" * 9)
#
# IndexError: list index out of range

# %%
tes = model.predict([df.userId, df.movieId])
# Out:
#    1/3152 [..............................] - ETA: 3:55
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 tes = model.predict([df.userId, df.movieId])
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'model_3/movies_embeddings/embedding_lookup' defined at (most recent call last):
#     File "C:\Users\Vincent\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\Vincent\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\Vincent\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\Vincent\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\Vincent\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in run_cell
#       result = self._run_cell(
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2995, in _run_cell
#       return runner(coro)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3194, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3373, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3433, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Vincent\AppData\Local\Temp\ipykernel_23916\128719125.py", line 1, in <module>
#       tes = model.predict([df.userId, df.movieId])
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\training.py", line 2350, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\training.py", line 2137, in predict_function
#       return step_function(self, iterator)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\training.py", line 2123, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\training.py", line 2111, in run_step
#       outputs = model.predict_step(data)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\training.py", line 2079, in predict_step
#       return self(x, training=False)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\training.py", line 561, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\functional.py", line 511, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\functional.py", line 668, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Vincent\anaconda3\lib\site-packages\keras\layers\core\embedding.py", line 208, in call
#       out = tf.nn.embedding_lookup(self.embeddings, inputs)
# Node: 'model_3/movies_embeddings/embedding_lookup'
# indices[14,0] = 46970 is not in [0, 9725)
# 	 [[{{node model_3/movies_embeddings/embedding_lookup}}]] [Op:__inference_predict_function_92164]

# %%
tes[4]
# Out:
# array([3.4973595], dtype=float32)

# %%
df_train[df_train.userId == 598]
# Out:
#        userId  movieId  rating   timestamp  \
# 92899   598.0    584.0     3.0  1498525383
# 94202   598.0   4619.0     3.0  1498521974
# 94201   598.0   4617.0     1.5  1498505002
# 94891   598.0   7963.0     2.5  1498532657
# 94489   598.0   5920.0     2.5  1498515064
# ...       ...      ...     ...         ...
# 93232   598.0   1348.0     2.5  1519146702
# 94939   598.0   8267.0     3.5  1498528415
# 93458   598.0   1957.0     2.5  1498513853
# 92766   598.0    311.0     2.5  1498517384
# 94790   598.0   7472.0     3.0  1498524675
#
#                                           title                         genres
# 92899                       Multiplicity (1996)                         Comedy
# 94202                           Elephant (2003)                          Drama
# 94201                      Scary Movie 3 (2003)                  Comedy|Horror
# 94891                      Robot & Frank (2012)            Comedy|Drama|Sci-Fi
# 94489                     Fantastic Four (2005)        Action|Adventure|Sci-Fi
# ...                                         ...                            ...
# 93232                     City of Angels (1998)          Drama|Fantasy|Romance
# 94939                   12 Years a Slave (2013)                          Drama
# 93458                       Lost & Found (1999)                 Comedy|Romance
# 92766                          Crow, The (1994)  Action|Crime|Fantasy|Thriller
# 94790  I Saw the Devil (Akmareul boatda) (2010)                 Crime|Thriller
#
# [2001 rows x 6 columns]
